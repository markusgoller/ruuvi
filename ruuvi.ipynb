# %% [markdown]
# # ruuvi

# %% [markdown]
# # see also

# %% [markdown]
# https://www.kite.com/python/answers/how-to-plot-data-from-a-csv-file-in-python
# https://realpython.com/pandas-plot-python/
# https://stackoverflow.com/questions/51174691/how-to-increase-image-size-of-pandas-dataframe-plot-in-jupyter-notebook/51174822

# %%
# %load_ext autoreload
# %autoreload
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Dataframe

# %%
df = pd.read_csv(
    './data/F6FC6F06E29B_1607356367676_119890203.csv'
)
df.head()
# Out:
#                   timestamp  temperature (°C)  humidity (%)  pressure (hPa)  \
# 0  2020-12-06T17:23:05+0100              5.86       64.2350          886.24
# 1  2020-12-06T17:23:08+0100              5.86       64.2350          886.23
# 2  2020-12-06T17:23:16+0100              5.86       64.2575          886.23
# 3  2020-12-06T17:23:23+0100              5.86       64.2575          886.23
# 4  2020-12-06T17:23:34+0100              5.86       64.2575          886.22
#
#    rssi  acceleration x  acceleration y  acceleration z  voltage  \
# 0   -66          -0.016           0.008           1.036    2.875
# 1   -63          -0.012           0.012           1.040    2.875
# 2   -91          -0.020           0.008           1.044    2.887
# 3   -80          -0.016           0.012           1.036    2.887
# 4   -93          -0.012           0.020           1.036    2.887
#
#    movement counter  measurement sequence number
# 0                99                        19695
# ...

# %%
df.describe()
# Out:
#        temperature (°C)  humidity (%)  pressure (hPa)        rssi  \
# count        191.000000    191.000000      191.000000  191.000000
# mean           5.152513     61.373835      887.982670  -73.214660
# std            0.816889      3.790686        2.320646   11.847762
# min            3.540000     53.732500      885.100000  -94.000000
# 25%            4.540000     60.491250      886.210000  -83.000000
# 50%            5.400000     62.955000      886.220000  -78.000000
# 75%            5.850000     64.267500      890.970000  -62.000000
# max            7.690000     64.610000      891.250000  -54.000000
#
#        acceleration x  acceleration y  acceleration z     voltage  \
# count      191.000000      191.000000      191.000000  191.000000
# mean        -0.015602        0.011518        1.039623    2.875911
# std          0.003729        0.003337        0.004442    0.008447
# min         -0.028000        0.004000        1.028000    2.851000
# ...

# %% [markdown]
# # Plots

# %%
df.plot(x='timestamp', y='temperature (°C)', figsize=(20,5), rot=30)
# Out:
# <AxesSubplot:xlabel='timestamp'>

# %%
df.plot(x='timestamp', y='pressure (hPa)', figsize=(20,5), rot=30)
# Out:
# <AxesSubplot:xlabel='timestamp'>

# %%
df.plot(x='timestamp', y='humidity (%)', figsize=(20,5), rot=30)
# Out:
# <AxesSubplot:xlabel='timestamp'>
